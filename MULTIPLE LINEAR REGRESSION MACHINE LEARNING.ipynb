# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
pd.read_csv("scrap price.csv")
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# ...

# %%
vehicle=pd.read_csv("scrap price.csv")

# %%
vehicle
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# ...

# %%
#checking for space
vehicle.isnull().sum()
# Out:
# ID                  0
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# ## extraction of independent and dependent variable

# %%
#multiple linear is used to estimate the relationship between 2 or more independent variables
#and one dependent variables
#x=[["enginesize","horsepower","compressionratio	","stroke"]]
#y=["price"]

# %%
#to locate all the columns in x,y
x=vehicle.iloc[0:,18:-1]
y=vehicle.iloc[0:,-1]

# %%
x
# Out:
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0         3.47    2.68               9.0         111     5000       21
# 1         3.47    2.68               9.0         111     5000       21
# 2         2.68    3.47               9.0         154     5000       19
# 3         3.19    3.40              10.0         102     5500       24
# 4         3.19    3.40               8.0         115     5500       18
# ..         ...     ...               ...         ...      ...      ...
# 200       3.78    3.15               9.5         114     5400       23
# 201       3.78    3.15               8.7         160     5300       19
# 202       3.58    2.87               8.8         134     5500       18
# 203       3.01    3.40              23.0         106     4800       26
# 204       3.78    3.15               9.5         114     5400       19
#
#      highwaympg
# 0            27
# 1            27
# 2            26
# 3            30
# 4            22
# ...

# %% [markdown]
# ## split x and y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
len(x_train)
# Out:
# 102

# %%
len(x_test)
# Out:
# 103

# %% [markdown]
# ## create a linear regression object

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
model=LinearRegression()

# %% [markdown]
# ## new file

# %%
import pandas as pd
pd.read_html("https://www.w3schools.com/python/python_ml_multiple_regression.asp")
# Out:
# [Empty DataFrame
#  Columns: [Car, Model, Volume, Weight, CO2, Unnamed: 5]
#  Index: [],
#               0           1     2     3    4
#  0       Toyota        Aygo  1000   790   99
#  1   Mitsubishi  Space Star  1200  1160   95
#  2        Skoda      Citigo  1000   929   95
#  3         Fiat         500   900   865   90
#  4         Mini      Cooper  1500  1140  105
#  5           VW         Up!  1000   929  105
#  6        Skoda       Fabia  1400  1109   90
#  7     Mercedes     A-Class  1500  1365   92
#  8         Ford      Fiesta  1500  1112   98
#  9         Audi          A1  1600  1150   99
#  10     Hyundai         I20  1100   980   99
#  11      Suzuki       Swift  1300   990  101
#  12        Ford      Fiesta  1000  1112   99
#  13       Honda       Civic  1600  1252   94
#  14      Hundai         I30  1600  1326   97
#  15        Opel       Astra  1600  1330   97
#  16         BMW           1  1600  1365   99
#  17       Mazda           3  2200  1280  104
# ...

# %%
data=pd.read_html("https://www.w3schools.com/python/python_ml_multiple_regression.asp")

# %%
data[1]
# Out:
#              0           1     2     3    4
# 0       Toyota        Aygo  1000   790   99
# 1   Mitsubishi  Space Star  1200  1160   95
# 2        Skoda      Citigo  1000   929   95
# 3         Fiat         500   900   865   90
# 4         Mini      Cooper  1500  1140  105
# 5           VW         Up!  1000   929  105
# 6        Skoda       Fabia  1400  1109   90
# 7     Mercedes     A-Class  1500  1365   92
# 8         Ford      Fiesta  1500  1112   98
# 9         Audi          A1  1600  1150   99
# 10     Hyundai         I20  1100   980   99
# 11      Suzuki       Swift  1300   990  101
# 12        Ford      Fiesta  1000  1112   99
# 13       Honda       Civic  1600  1252   94
# 14      Hundai         I30  1600  1326   97
# 15        Opel       Astra  1600  1330   97
# 16         BMW           1  1600  1365   99
# 17       Mazda           3  2200  1280  104
# 18       Skoda       Rapid  1600  1119  104
# 19        Ford       Focus  2000  1328  105
# ...

# %%
#assign back to data
data=data[1]

# %%
data[[2,3]]
# Out:
#        2     3
# 0   1000   790
# 1   1200  1160
# 2   1000   929
# 3    900   865
# 4   1500  1140
# 5   1000   929
# 6   1400  1109
# 7   1500  1365
# 8   1500  1112
# 9   1600  1150
# 10  1100   980
# 11  1300   990
# 12  1000  1112
# 13  1600  1252
# 14  1600  1326
# 15  1600  1330
# 16  1600  1365
# 17  2200  1280
# 18  1600  1119
# 19  2000  1328
# 20  1600  1584
# 21  2000  1428
# 22  2100  1365
# 23  1600  1415
# 24  2000  1415
# 25  1500  1465
# 26  2000  1490
# 27  2000  1725
# 28  1600  1523
# 29  2000  1705
# 30  2100  1605
# 31  2000  1746
# 32  1600  1235
# 33  1600  1390
# 34  1600  1405
# 35  2500  1395

# %%
x1=data[[2,3]]

# %%
data[4]
# Out:
# 0      99
# 1      95
# 2      95
# 3      90
# 4     105
# 5     105
# 6      90
# 7      92
# 8      98
# 9      99
# 10     99
# 11    101
# 12     99
# 13     94
# 14     97
# 15     97
# 16     99
# 17    104
# 18    104
# 19    105
# 20     94
# 21     99
# 22     99
# 23     99
# 24     99
# 25    102
# 26    104
# 27    114
# 28    109
# 29    114
# 30    115
# 31    117
# 32    104
# 33    108
# 34    109
# 35    120
# Name: 4, dtype: int64

# %%
y1=data[4]

# %% [markdown]
# ## split x and y

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.5,random_state=0)

# %% [markdown]
# ## create a linear regression

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
model=LinearRegression()

# %% [markdown]
# ## fit the model/train the mode

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## to make predictions

# %%
model.predict(x_train)
# Out:
# array([103.89121499,  99.7738627 ,  99.10403436, 102.62063515,
#         96.92604364,  95.52044994,  99.15636531, 102.58138693,
#         98.27982969,  99.82043725,  98.98628971,  99.66553763,
#        102.58818996, 102.535859  ,  99.68176023,  99.81520416,
#         94.70095507,  95.35194427])

# %%
#when a value to predict is not given eg 2300 not gvn u put it in in place of x_train
model.predict([[2300,800]])
# Out:
# array([104.33026383])

# %% [markdown]
# ## mean square error

# %%
#mean square error is the difference between the actual and the predicted
#mean square is the average squared difference between the actual value and the estimated values

# %% [markdown]
# ## to evaluate the model

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test,model.predict(x_test))
# Out:
# 64.61201276776048

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_train,model.predict(x_train))
# Out:
# 20.009235261225502
